# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_ROMS = np.log10([100,300,1000,2000,3000,5000,7000,10000,12000,50000,70000,100000,300000,1000000])
x_ROMS_bw = np.log10([100,300,1000,2000,3000,5000,7000,10000,12000,30000,50000,70000,100000,300000,1000000])
x_INALT = np.log10([100,300,1000,2000,3000,5000,7000,10000,12000,15000,20000,30000,
                    40000,50000,70000,100000,300000,1000000])
x_INALT_bw = np.log10([100,300,1000,2000,3000,5000,7000,10000,12000,30000,50000,70000,100000,
                       300000,1000000])
x_ROMS_child = np.log10([300,1000,3000,5000,7000,10000,12000,15000,30000,70000,100000,
                       300000,1000000])
x_ROMS_child_bw = np.log10([100,300,1000,2000,3000,5000,7000,10000,12000,15000,20000,
                            100000,300000,500000,1000000])

ROMS = [14.080240193977025,2902.1813535118094,7472.639677547076,10158.971736774367,18154.88987086821,
        32128.968115609478,31818.08872635519,32095.755965470995,28633.463737221588,35934.92262775994,
        34798.54119351793,36436.4958902142,36563.106517082495,
        36574.62359746051]
ROMS_bw=[79.26555427705077,3458.638193671517,5624.8119852564405,9132.731998023932,
         15488.677920219101,14694.117279836728,17311.14648750837,19074.09613089479,19205.87570348618,
         18859.393862394765,20035.389732177635,20370.765747410762,12677.840213261528,
         23663.979673547747,23584.29088660389]
INALT = [924.530415052423,5201.550649429819,12118.686752817961,17331.033416457743,
14628.026326614567,12268.365286238251,13838.092804485497,19328.190515609385,
17327.0830835821,15270.727135053208,12090.965701453611,22972.649166010913,
39831.958734210944,76316.94887516659,65680.4000736322,78981.40327649517,
74711.39971377143,76042.66701680231]
INALT_bw = [1085.0163870837082,1192.4160050677842,8947.348049226339,10633.184449522014,
            10616.06457102544,7740.317857132148,9088.792518575798,8593.756053592748,
            7923.885977241987,8285.433696475191,8005.353178372005,9283.849723628879,
            31248.013233649577,38983.45792084897,23775.92518180909]
ROMS_child = [34.90417186163526,936.7717604186008,2156.8294945920784,3444.9709781878464,
              3262.5931150345245,5214.767915781824,5544.5490008054085,6513.332546321277,
              8900.98575746495,8070.396270571854,8096.060835233096,7916.6794585823445,
              7373.613116076433]
ROMS_child_bw=[1.0909006084374182,356.8256013687404,704.5600595341688,1403.126441389962,
               1499.1696244407838,1865.0450593855746,2253.5502452611213,1594.004894251851,
               2117.0047017809607,1790.1899567840035,1680.5070300715022,1881.1206794638933,
               3415.593254844431,3536.9975362885575,3452.3970827985136]

  
plt.rcParams['font.size'] = 18
plt.rcParams['font.family'] = 'Arial'

fig, ax1 = plt.subplots(figsize=(8,6)) 

ax1.set_xlabel('Released particles')  
ax1.set_ylabel('Area [km²]', color = 'black')  
ax1.plot(x_INALT, np.log10(INALT), color = 'tab:blue',marker='o',label='INALT20, fw')
ax1.plot(x_INALT_bw, np.log10(INALT_bw), color = 'lightblue',marker='o',label='INALT20, bw')
ax1.plot(x_ROMS, np.log10(ROMS), color = 'tab:green',marker='o',label='ROMS (parent), fw')
ax1.plot(x_ROMS_bw, np.log10(ROMS_bw), color = 'darkseagreen',marker='o',label='ROMS (parent), bw') 
ax1.plot(x_ROMS_child, np.log10(ROMS_child), color = 'tab:brown',marker='o',label='ROMS (child), fw')
ax1.plot(x_ROMS_child_bw, np.log10(ROMS_child_bw), color = 'tan',marker='o',label='ROMS (child), bw')
ax1.tick_params(axis ='y', labelcolor = 'black')
ax1.set_yticks([0,1,2,3,4,5],[1,10,100,'1\u202F000','10\u202F000','100\u202F000'])
ax1.axis(xmin=1.9,xmax=6.1)
ax1.set_xticks([2,3,4,5,6],[100,'1\u202F000','10\u202F000','100\u202F000','1\u202F000\u202F000'])
legend=plt.legend()
legend.get_frame().set_alpha(0.0)

#ax2 = ax1.twinx()  
  
color = 'tab:brown'
#ax2.set_ylabel('ROMS (parent)', color = color)  
#ax2.plot(x_ROMS, np.log10(ROMS), color = 'tab:brown',marker='o')
#ax2.plot(x_ROMS_bw, np.log10(ROMS_bw), color = 'tan',marker='o') 
#ax2.tick_params(axis ='y', labelcolor = color)
#ax2.set_yticks([1,2,3,4,5],[10,100,1000,10000,100000])

#plt.vlines(5,1,5,color='red')
  
#plt.title('Spread area after 6 weeks dispersal\n(95% percentile)', fontweight ="bold",fontsize=14)
plt.savefig('../output_data/howmanyparticles.pdf', bbox_inches='tight')
  
plt.show()

# %%
x_ROMS = np.log10([100,300,1000,2000,3000,5000,7000,10000,12000,50000,70000,100000,300000,1000000])
x_INALT = np.log10([100,300,1000,2000,3000,5000,7000,10000,12000,15000,20000,30000,
                    40000,50000,70000,100000,300000,1000000])

ROMS = [14.080240193977025,2902.1813535118094,7472.639677547076,10158.971736774367,18154.88987086821,
        32128.968115609478,31818.08872635519,32095.755965470995,28633.463737221588,35934.92262775994,
        34798.54119351793,36436.4958902142,36563.106517082495,
        36574.62359746051]
INALT = [924.530415052423,5201.550649429819,12118.686752817961,17331.033416457743,
14628.026326614567,12268.365286238251,13838.092804485497,19328.190515609385,
17327.0830835821,15270.727135053208,12090.965701453611,22972.649166010913,
39831.958734210944,76316.94887516659,65680.4000736322,78981.40327649517,
74711.39971377143,76042.66701680231]   
  
fig, ax1 = plt.subplots()  
  
color = 'tab:blue'
ax1.set_xlabel('Released particles')  
ax1.set_ylabel('INALT', color = color)  
ax1.plot(x_INALT, np.log10(INALT), color = color,marker='o')
ax1.plot(x_ROMS, np.log10(ROMS), color = 'tab:brown',marker='o')  
ax1.tick_params(axis ='y', labelcolor = color)
ax1.set_yticks([2,3,4,5],[100,1000,10000,100000])
ax1.axis(xmin=1.9,xmax=6.1)
ax1.set_xticks([2,3,4,5,6],[100,1000,10000,100000,1000000])

ax2 = ax1.twinx()  
  
color = 'tab:brown'
ax2.set_ylabel('ROMS (parent)', color = color)  
#ax2.plot(x_ROMS, np.log10(ROMS), color = 'tab:brown',marker='o')   
ax2.tick_params(axis ='y', labelcolor = color)
ax2.set_yticks([1,2,3,4,5],[10,100,1000,10000,100000])

plt.vlines(4.69897,0,5,color='red')
  
plt.title('Spread area after 6 weeks dispersal [log10 km²]\n(95% percentile)', fontweight ="bold")  
  
plt.show()

# %%
x_ROMS = np.log10([10,30,100,300,1000,2000,3000,5000,7000,10000,12000,50000,70000,100000,300000,1000000])
x_INALT = np.log10([10,30,100,300,1000,2000,3000,5000,7000,10000,12000,15000,20000,30000,
                    40000,50000,70000,100000,300000,1000000])

ROMS = [1,1,14.080240193977025,2902.1813535118094,7472.639677547076,10158.971736774367,18154.88987086821,
        32128.968115609478,31818.08872635519,32095.755965470995,28633.463737221588,35934.92262775994,
        34798.54119351793,36436.4958902142,36563.106517082495,
        36574.62359746051
]
INALT = [1,1,924.530415052423,
5201.550649429819,
12118.686752817961,
17331.033416457743,
14628.026326614567,
12268.365286238251,
13838.092804485497,
19328.190515609385,
17327.0830835821,
15270.727135053208,
12090.965701453611,
22972.649166010913,
39831.958734210944,
76316.94887516659,
65680.4000736322,
78981.40327649517,
74711.39971377143,
76042.66701680231,
]  
  
fig, ax1 = plt.subplots()  
  
color = 'tab:blue'
ax1.set_xlabel('Released particles [log10]')  
ax1.set_ylabel('INALT', color = color)  
ax1.plot(x_INALT, (INALT), color = color)  
ax1.scatter(x_INALT, (INALT), color = color)  
ax1.tick_params(axis ='y', labelcolor = color) 
ax1.axis(xmin=0.5,xmax=6.2)

ax2 = ax1.twinx()  
  
color = 'tab:brown'
ax2.set_ylabel('ROMS (parent)', color = color)  
ax2.plot(x_ROMS, (ROMS), color = color)  
ax2.scatter(x_ROMS, (ROMS), color = color)  
ax2.tick_params(axis ='y', labelcolor = color)  

plt.vlines(4.69897,0,80000,color='red')
  
plt.title('Spread area after 6 weeks dispersal [m²]\n(95% percentile)', fontweight ="bold")  
  
plt.show()

# %%
x_ROMS = np.log10([10,29,97,288,979,1172,1467,1957,2927,4891,6804,9783,14676,
                  29269,48759,97567,976062])
x_INALT = np.log10([10,30,100,300,1000,1200,1500,2000,3000,5000,7000,9999,15000,30000,50000,100000,999993])

ROMS = [48.629959,39.402317025356446,47.7704173243895,43.27091384053673,
        46.2311460629414,45.5998797438327,
        43.8713651858715,44.4740530840137,44.7467344076521,44.27759133267614,
        44.86161085256762,45.0900250583926,44.79395373738683,44.98711740294586,45.05430580121966,
        44.95810829062457,44.977155940306105]
INALT = [11.495008183207162,
13.865395345335523,
13.869680894373872,
12.137951466696876,
10.954224023122654,
11.195295278082806,
11.712824703161441,
11.475875326774453,
11.552041678268553,
11.408366356991543,
11.640452009658981,
11.5503020834954,
11.542797256223459,
11.56289519377737,
11.531806019463088,
11.529366773392821,
11.54130934708532,
]  
  
fig, ax1 = plt.subplots()  
  
color = 'tab:blue'
ax1.set_xlabel('Released particles [log10]')  
ax1.set_ylabel('INALT', color = color)  
ax1.plot(x_INALT, INALT, color = color)  
ax1.scatter(x_INALT, INALT, color = color)  
ax1.tick_params(axis ='y', labelcolor = color) 
ax1.axis(xmin=0.5,xmax=6.2)

ax2 = ax1.twinx()  
  
color = 'tab:brown'
ax2.set_ylabel('ROMS', color = color)  
ax2.plot(x_ROMS, ROMS, color = color)  
ax2.scatter(x_ROMS, ROMS, color = color)  
ax2.tick_params(axis ='y', labelcolor = color)  
  
plt.title('Mean distance after 2 weeks dispersal [km]\n(95% percentile)', fontweight ="bold")  
  
plt.show()

# %%
x_ROMS = np.log10([10,27,91,270,921,1113,1362,1817,2711,4524,6304,9110,13577,27139,90479])
x_INALT = np.log10([6,23,80,231,738,881,1119,1471,2243,3677,5188,7425,11138,22336,74059])

ROMS = [48.629959,41.5645520693599,50.56819,45.9346378109643,49.0193815,
        48.0181731387287,47.0894663775947,47.7540315947247,
          48.1641511711346,47.74197531236349,48.285461684088766,48.31213,
        48.322096177303195,48.3845844944673,48.34377]
INALT = [19.40172,17.533101,17.421049,15.439216956,14.53897,14.881048367046896,
         15.37875988785087,15.26895942745639,
         15.1724300844641,15.272737154926677,15.415895309925167,
         15.2504084491848,15.263704386837421,15.2561131960862,15.275277]  
  
fig, ax1 = plt.subplots()  
  
color = 'tab:blue'
ax1.set_xlabel('Released particles [log10]')  
ax1.set_ylabel('INALT', color = color)  
ax1.plot(x_INALT, INALT, color = color)  
ax1.scatter(x_INALT, INALT, color = color)  
ax1.tick_params(axis ='y', labelcolor = color) 
ax1.axis(xmin=0.5,xmax=5.2)

ax2 = ax1.twinx()  
  
color = 'tab:brown'
ax2.set_ylabel('ROMS', color = color)  
ax2.plot(x_ROMS, ROMS, color = color)  
ax2.scatter(x_ROMS, ROMS, color = color)  
ax2.tick_params(axis ='y', labelcolor = color)  
  
plt.title('Mean distance after 2 weeks dispersal [km]\nwith minimum average speed $v_{min}=0.005 \dfrac{m}{s}$ on two consecutive days\n(95% percentile)', fontweight ="bold")  
  
plt.show()
